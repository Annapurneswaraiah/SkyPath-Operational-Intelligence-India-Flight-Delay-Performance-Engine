# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\asus\Python class\Intership\Airport_Operations_20k_Realistic.csv")

# %%
df.head()
# Out:
#   Flight_ID        Airline Origin Destination Aircraft_Type Terminal Gate  \
# 0  FL100000      Akasa Air    CCU         BOM          B777       T3   G9
# 1  FL100001        Vistara    BOM         MAA          B777       T2  G18
# 2  FL100002  Qatar Airways    MAA         CCU          B787       T1  G43
# 3  FL100003      Akasa Air    HYD         DEL          B777       T2  G24
# 4  FL100004       SpiceJet    BLR         CCU          A321       T1  G27
#
#   Weather_Condition          Flight_Date     Month  ... Passenger_Count  \
# 0              Rain  2025-02-09 00:00:00  February  ...             256
# 1             Clear  2025-06-17 00:00:00      June  ...              59
# 2             Clear  2025-04-19 00:00:00     April  ...             138
# 3             Clear  2025-10-08 00:00:00   October  ...             253
# 4             Clear  2025-02-25 00:00:00  February  ...              63
#
#   Load_Factor (%) Ground_Staff_Count  Baggage_Count  Fuel_Quantity_Liters  \
# ...

# %%
df.shape
# Out:
# (20000, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Flight_ID                     20000 non-null  object
#  1   Airline                       20000 non-null  object
#  2   Origin                        20000 non-null  object
#  3   Destination                   20000 non-null  object
#  4   Aircraft_Type                 20000 non-null  object
#  5   Terminal                      20000 non-null  object
#  6   Gate                          20000 non-null  object
#  7   Weather_Condition             20000 non-null  object
#  8   Flight_Date                   20000 non-null  object
#  9   Month                         20000 non-null  object
#  10  Scheduled_Departure           20000 non-null  object
#  11  Scheduled_Arrival             20000 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Flight_ID', 'Airline', 'Origin', 'Destination', 'Aircraft_Type',
#        'Terminal', 'Gate', 'Weather_Condition', 'Flight_Date', 'Month',
#        'Scheduled_Departure', 'Scheduled_Arrival', 'Status', 'Gate_Delay_Min',
#        'Fuel_Delay_Min', 'Baggage_Delay_Min', 'Catering_Delay_Min',
#        'Passenger_Transfer_Delay_Min', 'Cleaning_Delay_Min',
#        'Security_Delay_Min', 'Maintenance_Delay_Min', 'ATC_Delay_Min',
#        'Total_Delay_Min', 'Departure_Delay_Min', 'Arrival_Delay_Min',
#        'Passenger_Count', 'Load_Factor (%)', 'Ground_Staff_Count',
#        'Baggage_Count', 'Fuel_Quantity_Liters', 'Gate_Occupancy_Min',
#        'Turnaround_Time_Min', 'Actual_Departure', 'Actual_Arrival',
#        'Delay_Reason'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Flight_ID                        object
# Airline                          object
# Origin                           object
# Destination                      object
# Aircraft_Type                    object
# Terminal                         object
# Gate                             object
# Weather_Condition                object
# Flight_Date                      object
# Month                            object
# Scheduled_Departure              object
# Scheduled_Arrival                object
# Status                           object
# Gate_Delay_Min                    int64
# Fuel_Delay_Min                    int64
# Baggage_Delay_Min                 int64
# Catering_Delay_Min                int64
# Passenger_Transfer_Delay_Min      int64
# Cleaning_Delay_Min                int64
# Security_Delay_Min                int64
# Maintenance_Delay_Min             int64
# ATC_Delay_Min                     int64
# Total_Delay_Min                   int64
# ...

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Flight_ID                         0
# Airline                           0
# Origin                            0
# Destination                       0
# Aircraft_Type                     0
# Terminal                          0
# Gate                              0
# Weather_Condition                 0
# Flight_Date                       0
# Month                             0
# Scheduled_Departure               0
# Scheduled_Arrival                 0
# Status                            0
# Gate_Delay_Min                    0
# Fuel_Delay_Min                    0
# Baggage_Delay_Min                 0
# Catering_Delay_Min                0
# Passenger_Transfer_Delay_Min      0
# Cleaning_Delay_Min                0
# Security_Delay_Min                0
# Maintenance_Delay_Min             0
# ATC_Delay_Min                     0
# Total_Delay_Min                   0
# Departure_Delay_Min               0
# Arrival_Delay_Min                 0
# Passenger_Count                   0
# ...

# %%
rows_before=len(df)
df=df.drop_duplicates()
rows_after=len(df)
print("Rows before:",rows_before)
print("Rows after:",rows_after)
print("duplicates Removed:",rows_before-rows_after)
# Out:
# Rows before: 20000
# Rows after: 20000
# duplicates Removed: 0

# %%
numeric_cols=df.select_dtypes(include=["int64","float64"]).columns
for col in numeric_cols:
    df[col]=df[col].fillna(df[col].median())

# %%
categorical_cols=df.select_dtypes(include=["int64","float64"]).columns
for col in numeric_cols:
    df[col]=df[col].fillna(df[col].mode()[0])

# %%
df['Flight_Date ']=pd.to_datetime(df['Flight_Date'])
df.head()
# Out:
#   Flight_ID        Airline Origin Destination Aircraft_Type Terminal Gate  \
# 0  FL100000      Akasa Air    CCU         BOM          B777       T3   G9
# 1  FL100001        Vistara    BOM         MAA          B777       T2  G18
# 2  FL100002  Qatar Airways    MAA         CCU          B787       T1  G43
# 3  FL100003      Akasa Air    HYD         DEL          B777       T2  G24
# 4  FL100004       SpiceJet    BLR         CCU          A321       T1  G27
#
#   Weather_Condition          Flight_Date     Month  ... Load_Factor (%)  \
# 0              Rain  2025-02-09 00:00:00  February  ...           83.46
# 1             Clear  2025-06-17 00:00:00      June  ...           95.21
# 2             Clear  2025-04-19 00:00:00     April  ...           65.68
# 3             Clear  2025-10-08 00:00:00   October  ...           83.22
# 4             Clear  2025-02-25 00:00:00  February  ...           94.33
#
#   Ground_Staff_Count Baggage_Count  Fuel_Quantity_Liters  Gate_Occupancy_Min  \
# ...

# %%
df["Actual_Departure"] = pd.to_datetime(df["Actual_Departure"], errors="coerce")
df["Actual_Arrival"] = pd.to_datetime(df["Actual_Arrival"], errors="coerce")

# %%
df["Actual_Departure"] = df["Actual_Departure"].fillna(df["Actual_Departure"].mode()[0])

df["Actual_Arrival"] = df["Actual_Arrival"].fillna(df["Actual_Arrival"].mode()[0])

# %%
df["Actual_Departure"] = df["Actual_Departure"].fillna(method="ffill")

df["Actual_Arrival"] = df["Actual_Arrival"].fillna(method="ffill")
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_2328\3344216326.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Actual_Departure"] = df["Actual_Departure"].fillna(method="ffill")
# C:\Users\asus\AppData\Local\Temp\ipykernel_2328\3344216326.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Actual_Arrival"] = df["Actual_Arrival"].fillna(method="ffill")

# %%
print(df[["Actual_Departure", "Actual_Arrival"]].isnull().sum())
# Out:
# Actual_Departure    0
# Actual_Arrival      0
# dtype: int64

# %%
df["Flight_Date"] = pd.to_datetime(df["Flight_Date"], errors="coerce")

# %%
df["Actual_Departure"] = pd.to_datetime(df["Actual_Departure"], errors="coerce")

# %%
df["Actual_Arrival"] = pd.to_datetime(df["Actual_Arrival"], errors="coerce")

# %%
print(df[["Flight_Date", "Actual_Departure", "Actual_Arrival"]].dtypes)
# Out:
# Flight_Date         datetime64[ns]
# Actual_Departure    datetime64[ns]
# Actual_Arrival      datetime64[ns]
# dtype: object

# %%
missing_values = df.isnull().sum()
print(missing_values)
print(df.dtypes)
# Out:
# Flight_ID                       0
# Airline                         0
# Origin                          0
# Destination                     0
# Aircraft_Type                   0
# Terminal                        0
# Gate                            0
# Weather_Condition               0
# Flight_Date                     0
# Month                           0
# Scheduled_Departure             0
# Scheduled_Arrival               0
# Status                          0
# Gate_Delay_Min                  0
# Fuel_Delay_Min                  0
# Baggage_Delay_Min               0
# Catering_Delay_Min              0
# Passenger_Transfer_Delay_Min    0
# Cleaning_Delay_Min              0
# Security_Delay_Min              0
# Maintenance_Delay_Min           0
# ATC_Delay_Min                   0
# Total_Delay_Min                 0
# Departure_Delay_Min             0
# Arrival_Delay_Min               0
# Passenger_Count                 0
# Load_Factor (%)                 0
# ...

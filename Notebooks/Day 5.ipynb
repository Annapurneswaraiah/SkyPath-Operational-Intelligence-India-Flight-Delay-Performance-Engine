# %% [markdown]
# - Author cleaning plan (missing values, duplicates, type fixes, category harmonisation)
# - Decide keep / drop / impute rule for each affected column
# - Freeze cleaning plan v1 and commit to /docs

# %%
import pandas as pd

# %%
df=pd.read_csv("Airport_Operations_Dataset_Cleaned.csv", parse_dates=["Flight_Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Flight_ID                     20000 non-null  object
#  1   Airline                       20000 non-null  object
#  2   Origin                        20000 non-null  object
#  3   Destination                   20000 non-null  object
#  4   Aircraft_Type                 20000 non-null  object
#  5   Terminal                      20000 non-null  object
#  6   Gate                          20000 non-null  object
#  7   Weather_Condition             20000 non-null  object
#  8   Flight_Date                   20000 non-null  datetime64[ns]
#  9   Month                         20000 non-null  object
#  10  Scheduled_Departure           20000 non-null  object
#  11  Scheduled_Arrival             20000 non-null  object
# ...

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Flight_ID                         0
# Airline                           0
# Origin                            0
# Destination                       0
# Aircraft_Type                     0
# Terminal                          0
# Gate                              0
# Weather_Condition                 0
# Flight_Date                       0
# Month                             0
# Scheduled_Departure               0
# Scheduled_Arrival                 0
# Status                            0
# Gate_Delay_Min                    0
# Fuel_Delay_Min                    0
# Baggage_Delay_Min                 0
# Catering_Delay_Min                0
# Passenger_Transfer_Delay_Min      0
# Cleaning_Delay_Min                0
# Security_Delay_Min                0
# Maintenance_Delay_Min             0
# ATC_Delay_Min                     0
# Total_Delay_Min                   0
# Departure_Delay_Min               0
# Arrival_Delay_Min                 0
# Passenger_Count                   0
# ...

# %%
df["Departure_Minute"] = df["Departure_Minute"].fillna(0)
df["Arrival_Hour"] = df["Arrival_Hour"].fillna(0)
df["Arrival_Minute"] = df["Arrival_Minute"].fillna(0)

# %%
cols = ["Departure_Minute", "Arrival_Hour", "Arrival_Minute"]

df[cols] = df[cols].fillna(0)

# %%
print(df[cols].isnull().sum())
# Out:
# Departure_Minute    0
# Arrival_Hour        0
# Arrival_Minute      0
# dtype: int64

# %%
print(df[["Departure_Minute", "Arrival_Hour", "Arrival_Minute"]].dtypes(int))

print(df[["Departure_Minute", "Arrival_Hour", "Arrival_Minute"]].head())

print(df[["Departure_Minute", "Arrival_Hour", "Arrival_Minute"]].isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 print(df[["Departure_Minute", "Arrival_Hour", "Arrival_Minute"]].dtypes(int))
#       3 print(df[["Departure_Minute", "Arrival_Hour", "Arrival_Minute"]].head())
#       5 print(df[["Departure_Minute", "Arrival_Hour", "Arrival_Minute"]].isnull().sum())
#
# TypeError: 'Series' object is not callable

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Flight_ID                         0
# Airline                           0
# Origin                            0
# Destination                       0
# Aircraft_Type                     0
# Terminal                          0
# Gate                              0
# Weather_Condition                 0
# Flight_Date                       0
# Month                             0
# Scheduled_Departure               0
# Scheduled_Arrival                 0
# Status                            0
# Gate_Delay_Min                    0
# Fuel_Delay_Min                    0
# Baggage_Delay_Min                 0
# Catering_Delay_Min                0
# Passenger_Transfer_Delay_Min      0
# Cleaning_Delay_Min                0
# Security_Delay_Min                0
# Maintenance_Delay_Min             0
# ATC_Delay_Min                     0
# Total_Delay_Min                   0
# Departure_Delay_Min               0
# Arrival_Delay_Min                 0
# Passenger_Count                   0
# ...

# %%
df["Year"] = df["Flight_Date"].dt.year
df["Month"] = df["Flight_Date"].dt.month
df["Day"] = df["Flight_Date"].dt.day

# %%
df.head()
# Out:
#   Flight_ID        Airline Origin Destination Aircraft_Type Terminal Gate  \
# 0  FL100000      Akasa Air    CCU         BOM          B777       T3   G9
# 1  FL100001        Vistara    BOM         MAA          B777       T2  G18
# 2  FL100002  Qatar Airways    MAA         CCU          B787       T1  G43
# 3  FL100003      Akasa Air    HYD         DEL          B777       T2  G24
# 4  FL100004       SpiceJet    BLR         CCU          A321       T1  G27
#
#   Weather_Condition Flight_Date  Month  ...       Actual_Arrival Delay_Reason  \
# 0              Rain  2025-02-09      2  ...  2025-02-09 17:18:00     No Delay
# 1             Clear  2025-06-17      6  ...  2025-06-17 13:38:00     No Delay
# 2             Clear  2025-04-19      4  ...  2025-04-19 13:54:00     No Delay
# 3             Clear  2025-10-08     10  ...  2025-10-08 23:29:00     No Delay
# 4             Clear  2025-02-25      2  ...  2025-02-26 01:17:00  Maintenance
#
# ...

# %% [markdown]
# ### Freeze cleaning plan v1 and commit to /docs
# - Fill the missing value
# - checking the duplicates records
# - Fix the datatypes
# - create new columns Actual depature time, Actual Arrival time separate

# %%
print(df.dtypes)
# Out:
# Flight_ID                               object
# Airline                                 object
# Origin                                  object
# Destination                             object
# Aircraft_Type                           object
# Terminal                                object
# Gate                                    object
# Weather_Condition                       object
# Flight_Date                     datetime64[ns]
# Month                                    int32
# Scheduled_Departure                     object
# Scheduled_Arrival                       object
# Status                                  object
# Gate_Delay_Min                           int64
# Fuel_Delay_Min                           int64
# Baggage_Delay_Min                        int64
# Catering_Delay_Min                       int64
# Passenger_Transfer_Delay_Min             int64
# Cleaning_Delay_Min                       int64
# Security_Delay_Min                       int64
# ...

# %%
df.to_csv("Airport_Operations_Dataset_Cleaned5.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df.to_csv("Airport_Operations_Dataset_Cleaned5.csv", index=False)
#
# File c:\Users\asus\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
new=pd.read_csv("Airport_Operations_Dataset_Cleaned5.csv",parse_dates=['Flight_Date'])

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Flight_ID                     20000 non-null  object
#  1   Airline                       20000 non-null  object
#  2   Origin                        20000 non-null  object
#  3   Destination                   20000 non-null  object
#  4   Aircraft_Type                 20000 non-null  object
#  5   Terminal                      20000 non-null  object
#  6   Gate                          20000 non-null  object
#  7   Weather_Condition             20000 non-null  object
#  8   Flight_Date                   20000 non-null  datetime64[ns]
#  9   Month                         20000 non-null  int64
#  10  Scheduled_Departure           20000 non-null  object
#  11  Scheduled_Arrival             20000 non-null  object
# ...
